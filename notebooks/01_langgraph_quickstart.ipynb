# %% [markdown]
# # LangGraph Quickstart Notebook\n
# This notebook demonstrates a minimal deterministic graph first, then shows where model-powered agents fit.

# %%
from langgraph_expts.graphs.basic_graph import run_basic_text_graph

result = run_basic_text_graph("getting started with")
result
# Out:
# {'text': 'getting started with hello langgraph'}
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langgraph_expts.config import load_settings

settings = load_settings()
{
    "OPENAI_API_KEY_set": bool(settings.openai_api_key),
    "ANTHROPIC_API_KEY_set": bool(settings.anthropic_api_key),
    "LANGSMITH_API_KEY_set": bool(settings.langsmith_api_key),
}
# Out:
# {'OPENAI_API_KEY_set': True,
#  'ANTHROPIC_API_KEY_set': True,
#  'LANGSMITH_API_KEY_set': True}

# %% [markdown]
# ## Next\n
# - Add a model-backed loop agent using LangGraph conditional edges.\n
# - Compare Graph API vs Functional API.\n
# - Log observations in the repository README.
